# %% [markdown]
# ___
#
# ___
# # GreenWood Project - Python Course:
#
# ## Exercises + Solutions - Pandas-Matplotlib
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>One Exercise</b> to Rull Them All
# </div>

# %% [markdown]
# We'll be doing data analysis on a dataset from World Gold Council
# ### Major Fiat Currencies Can't Compete With Gold
#
# https://www.gold.org/goldhub/data/gold-prices

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="700"/>
# </div>

# %% [markdown]
# **1. Do all the needed imports necessary for dealing with pandas and matplotlib**

# %% [markdown]
# **2. Read csv file '1978_Monthly_Gold_Prices.csv' data into a pandas dataframe and show first 5 rows**
#
# Always store your raw data in a dataframe and create another dataframe to perform your operations

# %% [markdown]
# **3. Print dataframe columns**

# %% [markdown]
# **3. Do pre-processing on your data so all values can be floats,make sure your indexes are datetimes type**
#
# Any non-necessary or duplicate column must be deleted using
#
# <code>df.drop(columns=['Column1 To delete','Col2 to delete',...],inplace=True)</code>

# %% [markdown]
# **4. Choose a style for plotting later**

# %% [markdown]
# **5. We would like to transform The NaN values preceeding a first float value to that first float value for each column**
#
# hint : <code>np.isnan()</code> method applied to a numeric returns True if NaN else False

# %% [markdown]
# **5. Normalize your data by the first value of each currency**

# %% [markdown]
# **6. Plot your normalized data, What can you conclude about certain currencies ?**

# %% [markdown]
# **7. Now Select currencies where normalized values are no more than 50**

# %% [markdown]
# **8. Now Since our currencies represent a value against Gold, What would be a proper dataframe where we store gold values against currencies, plot this new dataframe and conclude**

# %% [markdown]
# **9. Now plot previous dataframe starting 2006**

# %% [markdown]
# **We have only compared gold prices to currencies, now imagine if we built a dataset where we calculate a same basket of goods(real-estate, energy, food, education, health,...) a currency can buy you through times**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Bear Mind</b> Fiat Currencies always go back to their intrinsic value.
# </div>
